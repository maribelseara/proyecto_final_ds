# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Análisis de datos exploratorio

# %%
df=pd.read_csv('veh_usados_clean.csv')
df.head(5)
# Out:
#    Unnamed: 0 Fecha extrac                                             Enlace  \
# 0           0   2023-11-11  https://www.autoscout24.es/anuncios/lynk-co-01...
# 1           1   2023-11-11  https://www.autoscout24.es/anuncios/cupra-form...
# 2           2   2023-11-11  https://www.autoscout24.es/anuncios/gmc-yukon-...
# 3           3   2023-11-11  https://www.autoscout24.es/anuncios/infiniti-q...
# 4           4   2023-11-11  https://www.autoscout24.es/anuncios/audi-r8-4-...
#
#        Marca     Modelo    Precio  \
# 0  Lynk & Co         01  226301.0
# 1      Cupra  Formentor   20995.0
# 2        GMC      Yukon   79000.0
# 3   Infiniti        Q50   27250.0
# 4       Audi         R8   51500.0
#
#                                         Localización  Potencia Tipo vendedor  \
# 0  https://maps.google.com/?q=AVENIDA%20CARLOS%20...     197.0         Prof.
# 1  https://maps.google.com/?q=AVENIDA%20DE%20CATA...     150.0         Prof.
# ...

# %%
df['Localización'][1]
# Out:
# 'https://maps.google.com/?q=AVENIDA%20DE%20CATALU%C3%91A%20103%2C%2050014%20ZARAGOZA%2C%20ES'
